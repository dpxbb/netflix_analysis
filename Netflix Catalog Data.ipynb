# %% [markdown]
# #### Importing Enviroments

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# #### Netflix csv file

# %%
netflix = pd.read_csv('../files/netflix_titles.csv', sep=',', na_filter= False, na_values=['nan'], keep_default_na=False)

# %%
# nf = netflix[netflix[['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added','release_year', 'rating', 'duration', 'listed_in', 'description']].notnull().all(1)]

# netflix.loc[~netflix['date_added'].str.contains('NaN')]

# %%
nfMovies = netflix.loc[netflix['type'] == 'Movie']
nfMoviesUS = nfMovies.loc[nfMovies['country'].str.contains('United States')]

nfTV = netflix.loc[netflix['type'] == 'TV Show']
nfTVUS = nfTV.loc[netflix['country'].str.contains('United States')]
# nf.groupby(['type']).mean()

# nf.loc[(nf['type']== 'Movie') & (nf['country'].str.contains('United States')) & (nf['date_added'].str.contains('2019'))]

# %%
netflix
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1
# 2
# 3
# 4             Fernando Lebrija
# ...

# %%
nfMovies['listed_in'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
# Out:
#  Comedies                     310.0
# Children & Family Movies      358.0
# Stand-Up Comedy               273.0
# Comedies                      803.0
#  Sci-Fi & Fantasy             183.0
#  Thrillers                    352.0
# International Movies           85.0
# Action & Adventure            597.0
#  Dramas                       546.0
#  International Movies        1842.0
#  Independent Movies           534.0
# Cult Movies                    10.0
#  Romantic Movies              374.0
# Documentaries                 644.0
# Horror Movies                 205.0
# Dramas                       1077.0
#  Music & Musicals             231.0
# Anime Features                 12.0
#  Faith & Spirituality          47.0
#  Horror Movies                 57.0
# Independent Movies             18.0
#  LGBTQ Movies                  60.0
#  Cult Movies                   45.0
# Movies                         56.0
# Thrillers                      40.0
# Classic Movies                 62.0
# ...

# %%
nfMoviesUS['listed_in'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
# Out:
#  Comedies                    179.0
# Children & Family Movies     245.0
# Comedies                     268.0
#  Sci-Fi & Fantasy            127.0
#  Thrillers                   169.0
# International Movies           4.0
# Action & Adventure           247.0
#  Dramas                      184.0
#  International Movies        112.0
#  Independent Movies          273.0
#  Romantic Movies             131.0
# Documentaries                382.0
# Horror Movies                108.0
# Dramas                       349.0
# Stand-Up Comedy              181.0
#  Music & Musicals             70.0
# Anime Features                 2.0
#  Faith & Spirituality         28.0
# Independent Movies            14.0
#  LGBTQ Movies                 39.0
#  Cult Movies                  29.0
# Movies                        23.0
# Thrillers                     33.0
# Classic Movies                44.0
#  Horror Movies                37.0
#  Sports Movies                84.0
#  Stand-Up Comedy               5.0
# ...

# %%
netflix.loc[netflix['date_added'].str.contains('2015')]
netflix.loc[netflix['date_added'].str.contains('2016')]
netflix.loc[netflix['date_added'].str.contains('2017')]
netflix.loc[netflix['date_added'].str.contains('2018')]
netflix.loc[netflix['date_added'].str.contains('2019')]
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 34    80221550  TV Show               Archibald's Next Big Thing
# 35    81154455    Movie                               Article 15
# 36    81113928    Movie                    Care of Kancharapalem
# 37    81052275    Movie                    Ee Nagaraniki Emaindi
# ...        ...      ...                                      ...
# 6209  70264078  TV Show                                Mr. Young
# 6215  80066227  TV Show                      Crazy Ex-Girlfriend
# 6217  70196145  TV Show                                 New Girl
# 6218  80162994  TV Show                  Talking Tom and Friends
# 6219  80186475  TV Show                       Pokémon the Series
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 34
# 35               Anubhav Sinha
# 36              Maha Venkatesh
# 37             Tharun Bhascker
# ...

# %%
nfMoviesUS.loc[nfMoviesUS['date_added'].str.contains('2019')]
# Out:
#        show_id   type                                     title  \
# 27    80203094  Movie                               City of Joy
# 30    80988892  Movie                                  Next Gen
# 31    80239639  Movie                 Sierra Burgess Is A Loser
# 32    80159586  Movie  The Most Assassinated Woman in the World
# 40    80058026  Movie                             Hell and Back
# ...        ...    ...                                       ...
# 5541  60036359  Movie                          Schindler's List
# 5542  80049281  Movie                      Secret in Their Eyes
# 5544  70099610  Movie                               The Duchess
# 5545  80217041  Movie              The Search for Life in Space
# 5546  80156408  Movie                                       Una
#
#                          director  \
# 27                Madeleine Gavin
# 30    Kevin R. Adams, Joe Ksander
# 31                    Ian Samuels
# 32                 Franck Ribière
# ...

# %%
nfMoviesUS.loc[nfMoviesUS['date_added'].str.contains('2018')]
# Out:
#        show_id   type                                     title  \
# 27    80203094  Movie                               City of Joy
# 30    80988892  Movie                                  Next Gen
# 31    80239639  Movie                 Sierra Burgess Is A Loser
# 32    80159586  Movie  The Most Assassinated Woman in the World
# 40    80058026  Movie                             Hell and Back
# ...        ...    ...                                       ...
# 5541  60036359  Movie                          Schindler's List
# 5542  80049281  Movie                      Secret in Their Eyes
# 5544  70099610  Movie                               The Duchess
# 5545  80217041  Movie              The Search for Life in Space
# 5546  80156408  Movie                                       Una
#
#                          director  \
# 27                Madeleine Gavin
# 30    Kevin R. Adams, Joe Ksander
# 31                    Ian Samuels
# 32                 Franck Ribière
# ...

# %%
nfMoviesUS.loc[nfMoviesUS['date_added'].str.contains('2017')]
# Out:
#        show_id   type                    title                  director  \
# 4     80125979  Movie             #realityhigh          Fernando Lebrija
# 6     70304989  Movie                 Automata               Gabe Ibáñez
# 9     70304990  Movie              Good People         Henrik Ruben Genz
# 11    70299204  Movie  Kidnapping Mr. Heineken          Daniel Alfredson
# 20    80060297  Movie        Manhattan Romance               Tom O'Brien
# ...        ...    ...                      ...                       ...
# 5559  80081955  Movie     Five Nights in Maine              Maris Curran
# 5563  80125512  Movie                 Lavender          Ed Gass-Donnelly
# 5564  70129457  Movie                 Life 2.0       Jason Spingarn-Koff
# 5570  80104318  Movie          Silicon Cowboys               Jason Cohen
# 5572  80097468  Movie             The Bad Kids  Keith Fulton, Louis Pepe
#
#                                                    cast  \
# ...

# %%
nfMoviesUS16 = nfMoviesUS.loc[nfMoviesUS['date_added'].str.contains('2016')]
nfMoviesUS16

movieCount16 = nfMoviesUS16['date_added'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
movieCount16
# Out:
#  2016           142.0
# September 30      1.0
# September 23      2.0
# September 20      1.0
# September 16      4.0
#                 ...
# April 29          2.0
# April 22          2.0
# April 20          1.0
# April 15          2.0
# April 1           4.0
# Length: 87, dtype: float64

# %%
movieGenre = nfMoviesUS['listed_in'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
movieGenre.sort_values(ascending=False)
# Out:
# Documentaries                382.0
# Dramas                       349.0
#  Independent Movies          273.0
# Comedies                     268.0
# Action & Adventure           247.0
# Children & Family Movies     245.0
#  Dramas                      184.0
# Stand-Up Comedy              181.0
#  Comedies                    179.0
#  Thrillers                   169.0
#  Romantic Movies             131.0
#  Sci-Fi & Fantasy            127.0
#  International Movies        112.0
# Horror Movies                108.0
#  Sports Movies                84.0
#  Music & Musicals             70.0
# Classic Movies                44.0
#  LGBTQ Movies                 39.0
#  Horror Movies                37.0
# Thrillers                     33.0
#  Cult Movies                  29.0
#  Faith & Spirituality         28.0
# Movies                        23.0
#  Documentaries                19.0
#  Classic Movies               17.0
# Independent Movies            14.0
#  Children & Family Movies     13.0
# ...

# %%
nfTV['listed_in'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
# Out:
# Kids' TV                         288.0
#  International TV Shows          431.0
#  Spanish-Language TV Shows       116.0
# Crime TV Shows                   309.0
#  Science & Nature TV              67.0
# Docuseries                       148.0
#  Romantic TV Shows               257.0
#  TV Comedies                     347.0
# International TV Shows           570.0
#  TV Dramas                       543.0
#  TV Thrillers                     44.0
# Romantic TV Shows                 21.0
#  TV Mysteries                     69.0
# TV Comedies                       89.0
#  Docuseries                      131.0
# British TV Shows                 210.0
#  Reality TV                       90.0
#  TV Action & Adventure            96.0
#  Teen TV Shows                    44.0
#  Korean TV Shows                 132.0
# Reality TV                        63.0
# Anime Series                     117.0
#  Crime TV Shows                   54.0
# TV Horror                          9.0
# ...

# %%
usTVGenre = nfTVUS['listed_in'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)
usTVGenre.sort_values(ascending=False)
# Out:
# Kids' TV                         149.0
#  TV Dramas                       137.0
#  TV Comedies                     115.0
# Crime TV Shows                   110.0
# Docuseries                        92.0
# TV Comedies                       80.0
# TV Dramas                         52.0
#  TV Sci-Fi & Fantasy              50.0
#  TV Mysteries                     44.0
# Reality TV                        44.0
#  TV Action & Adventure            44.0
#  Docuseries                       42.0
#  International TV Shows           33.0
#  Science & Nature TV              31.0
# TV Action & Adventure             29.0
# Stand-Up Comedy & Talk Shows      26.0
#  Spanish-Language TV Shows        24.0
#  TV Thrillers                     23.0
# International TV Shows            23.0
#  Reality TV                       23.0
# British TV Shows                  22.0
#  TV Horror                        21.0
# Romantic TV Shows                 21.0
#  Teen TV Shows                    20.0
# ...

# %%
nfTVUS.loc[nfTVUS['date_added'].str.contains('2019')]
# Out:
#        show_id     type                                     title director  \
# 105   80241248  TV Show                            The Politician
# 135   81004814  TV Show                                   BONDING
# 160   80184771  TV Show  Inside Bill's Brain: Decoding Bill Gates
# 164   80244627  TV Show               Two Sentence Horror Stories
# 198   70178604  TV Show                            Ancient Aliens
# ...        ...      ...                                       ...      ...
# 6193  80049277  TV Show                         Ash vs. Evil Dead
# 6194  80046347  TV Show                              Señora Acero
# 6197  80987209  TV Show                      Rica, Famosa, Latina
# 6215  80066227  TV Show                       Crazy Ex-Girlfriend
# 6217  70196145  TV Show                                  New Girl
#
#                                                    cast  \
# 105   Ben Platt, Gwyneth Paltrow, Jessica Lange, Zoe...
# ...

# %%
nfTVUS.loc[nfTVUS['date_added'].str.contains('2018')]
# Out:
#        show_id     type                                             title  \
# 2     70234439  TV Show                                Transformers Prime
# 3     80058654  TV Show                  Transformers: Robots in Disguise
# 63    80996949  TV Show                             Adam Ruins Everything
# 64    80239337  TV Show                                            Ben 10
# 66    81011682  TV Show  Christiane Amanpour: Sex & Love Around the World
# ...        ...      ...                                               ...
# 6144  80171452  TV Show                             Dinotrux Supercharged
# 6172  80185074  TV Show                                Splash and Bubbles
# 6203  70158329  TV Show                    Star Trek: The Next Generation
# 6207  80190407  TV Show                                 Murderous Affairs
# 6216  80108373  TV Show                  The Magic School Bus Rides Again
#
#      director                                               cast  \
# ...

# %%
nfTVUS.loc[nfTVUS['date_added'].str.contains('2017')]
# Out:
#        show_id     type                             title director  \
# 8     80117902  TV Show                      Fire Chasers
# 54    80113482  TV Show                       No Tomorrow
# 61    80113641  TV Show                         Frequency
# 182   80176878  TV Show                           Manhunt
# 369   70208520  TV Show                         High Risk
# ...        ...      ...                               ...      ...
# 6166  70142437  TV Show                           Jericho
# 6183  80025601  TV Show                      The Get Down
# 6200  80018869  TV Show                    Liv and Maddie
# 6201  80050007  TV Show  The Mr. Peabody and Sherman Show
# 6214  80049872  TV Show                           Chelsea
#
#                                                    cast        country  \
# 8                                                        United States
# 54    Joshua Sasse, Tori Anderson, Jonathan Langdon,...  United States
# ...

# %%
nfCountry = netflix['country'].str.get_dummies(',').replace(0,np.nan).stack().sum(level=1)

nfCountry.sort_values(ascending=False)
# Out:
# United States     2302.0
# India              808.0
# United Kingdom     483.0
#  United States     308.0
# Canada             206.0
#                    ...
# Slovenia             1.0
#  Montenegro          1.0
#  Liechtenstein       1.0
#  Botswana            1.0
# Cyprus               1.0
# Length: 172, dtype: float64

# %% [markdown]
# ### Creating Parameters

# %% [markdown]
# The entire catalog of Movies:
# - nfMovies
#
# The entire catalog of TV Shows:
# - nfTV

# %%
# netflix.describe() -- won't show me much 
# Read Headers
netflix.columns
# Read Columns
netflix['date_added'][:15]

# read each Row
#netflix.iloc[1:5]

# for index, row in netflix.iterrows():
#     print (index, row['title'])
netflixTV = netflix.loc[netflix['type']=='TV Show']
netflixMovie = netflix.loc[netflix['type'] == 'Movie']

# sort values
#netflix.sort_values(["title", 'director'])

#read a specific location
# netflix.iloc[2,1] -- reads as TV show
#minYear = netflix['date_added'].loc['min']

# %% [markdown]
# ### Making Changes to Data

# %%
netflixMovie.loc[netflixMovie['date_added'] == '2019']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %% [markdown]
# #### Questions

# %% [markdown]
# 1. What content is available in different countries?
# 2. Is Netflix focused more on TV
# 3. How long is the average movie?
# 4. What has more content: TV or movies?
# 5. Which 3 countries are most represented in Netflix content?
# 6. Which 3 are least represented?
# 7. What is the percentage of content that comes from each continent?
# 8. What is the average TV rating on netflix?
# 9. What is the average movie rating?
# 10. What percentage of movies came out in the 70s? 80s? 90s? (etc.)
# 11. Which genre is best represented in TV?
# 12. Which genre is best represented in Movies?
# 13. Which genre is least represented?
# 14. What percentage of Horror movies are also Thrillers? (interchange with whatever genre mix, that’s the first that came to mind)
# 15. What percentage of content is fictional?
# 16. What percentage of content is documentary/educational/reality tv?
# 17. What genre is best represented in movies from India? Asia? The US? Each continent?
# 18. Which year produced the most content on average?
# 19. On average, how many movies/tv are added from each year? Or added each year?
# 20. Which director is best represented?
# 22. How many different directors are there from each country?

# %%
# netflix.loc[(netflix['type'] =='TV Show') & (netflix['country'].str.conins('United States')) & (netflix['date_added'].str.contains('2019'))]

# %%
nfMovies.loc[nfMovies['date_added'].str.contains('2015')]
# nfTV.loc[nfTV['date_added'].str.contains('2015')]
# Out:
#        show_id   type                                              title  \
# 25    80045922  Movie                                            6 Years
# 85    80019931  Movie                   Monster High: Boo York, Boo York
# 141   80059432  Movie                                   SMOSH: The Movie
# 176   80017275  Movie                                         Miss Julie
# 196   80066798  Movie                Keith Richards: Under the Influence
# 251   80033772  Movie              Cowspiracy: The Sustainability Secret
# 426   80031666  Movie        Winter on Fire: Ukraine's Fight for Freedom
# 473   70266684  Movie                                             Kristy
# 513   80045783  Movie                             Manson Family Vacation
# 545   80062011  Movie  Walt Disney Animation Studios Short Films Coll...
# 577   80038442  Movie                                            Results
# 620   80046779  Movie                         Anjelah Johnson: Not Fancy
# ...
